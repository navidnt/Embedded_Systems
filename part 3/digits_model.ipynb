# %%
import math
import numpy as np
from sklearn.datasets import load_digits
import tensorflow as tf
from tensorflow.keras import layers
#from tinymlgen import port


def get_data():
    np.random.seed(1337)
    x_values, y_values = load_digits(return_X_y=True)
    x_values /= x_values.max()
    # reshape to (8 x 8 x 1)
    x_values = x_values.reshape((len(x_values), 8, 8, 1))

    # split into train, validation, test
    TRAIN_SPLIT = int(0.6 * len(x_values))
    TEST_SPLIT = int(0.2 * len(x_values) + TRAIN_SPLIT)
    x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
    y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])

    return x_train, x_test, x_validate, y_train, y_test, y_validate

def get_model():
    x_train, x_test, x_validate, y_train, y_test, y_validate = get_data()

    # create a CNN
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(8, (3, 3), activation='relu', input_shape=(8, 8, 1)))
    model.add(layers.Flatten())
    model.add(layers.Dense(len(np.unique(y_train))))


    model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
    model.fit(x_train, y_train, epochs=50, batch_size=16,
              validation_data=(x_validate, y_validate))
    return model, x_test, y_test


def test_model(model, x_test, y_test):
    x_test = (x_test / x_test.max()).reshape((len(x_test), 8, 8, 1))
    y_pred = model.predict(x_test).argmax(axis=1)
    print('ACCURACY', (y_pred == y_test).sum() / len(y_test))
    exit()


if __name__ == '__main__':
    model, x_test, y_test = get_model()
    test_model(model, x_test, y_test)
    #c_code = port(model, variable_name='digits_model', pretty_print=True, optimize=False)
    #print(c_code)
# Out:
# Epoch 1/50
# 68/68 [==============================] - 1s 7ms/step - loss: 2.0456 - accuracy: 0.4777 - val_loss: 1.6641 - val_accuracy: 0.7583
# Epoch 2/50
# 68/68 [==============================] - 0s 4ms/step - loss: 1.1755 - accuracy: 0.8571 - val_loss: 0.9455 - val_accuracy: 0.8194
# Epoch 3/50
# 68/68 [==============================] - 0s 4ms/step - loss: 0.6024 - accuracy: 0.9007 - val_loss: 0.6693 - val_accuracy: 0.8417
# Epoch 4/50
# 68/68 [==============================] - 0s 4ms/step - loss: 0.3817 - accuracy: 0.9239 - val_loss: 0.5793 - val_accuracy: 0.8333
# Epoch 5/50
# 68/68 [==============================] - 0s 5ms/step - loss: 0.2811 - accuracy: 0.9378 - val_loss: 0.5349 - val_accuracy: 0.8556
# Epoch 6/50
# 68/68 [==============================] - 0s 4ms/step - loss: 0.2315 - accuracy: 0.9416 - val_loss: 0.5059 - val_accuracy: 0.8556
# Epoch 7/50
# 68/68 [==============================] - 0s 4ms/step - loss: 0.1967 - accuracy: 0.9490 - val_loss: 0.5082 - val_accuracy: 0.8472
# Epoch 8/50
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1693 - accuracy: 0.9564 - val_loss: 0.4864 - val_accuracy: 0.8556
# Epoch 9/50
# 68/68 [==============================] - 0s 4ms/step - loss: 0.1510 - accuracy: 0.9620 - val_loss: 0.4612 - val_accuracy: 0.8583
# Epoch 10/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1385 - accuracy: 0.9629 - val_loss: 0.4365 - val_accuracy: 0.8750
# Epoch 11/50
# 68/68 [==============================] - 0s 4ms/step - loss: 0.1253 - accuracy: 0.9703 - val_loss: 0.4442 - val_accuracy: 0.8778
# Epoch 12/50
# 68/68 [==============================] - 0s 4ms/step - loss: 0.1158 - accuracy: 0.9666 - val_loss: 0.4520 - val_accuracy: 0.8722
# Epoch 13/50
# 68/68 [==============================] - 0s 4ms/step - loss: 0.1083 - accuracy: 0.9740 - val_loss: 0.4371 - val_accuracy: 0.8806
# Epoch 14/50
# 68/68 [==============================] - 0s 4ms/step - loss: 0.0986 - accuracy: 0.9731 - val_loss: 0.4230 - val_accuracy: 0.8833
# Epoch 15/50
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0930 - accuracy: 0.9777 - val_loss: 0.4160 - val_accuracy: 0.8889
# Epoch 16/50
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0886 - accuracy: 0.9787 - val_loss: 0.4533 - val_accuracy: 0.8750
# Epoch 17/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0842 - accuracy: 0.9787 - val_loss: 0.4592 - val_accuracy: 0.8778
# Epoch 18/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0786 - accuracy: 0.9824 - val_loss: 0.4524 - val_accuracy: 0.8778
# Epoch 19/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0759 - accuracy: 0.9787 - val_loss: 0.4375 - val_accuracy: 0.8778
# Epoch 20/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0718 - accuracy: 0.9852 - val_loss: 0.4478 - val_accuracy: 0.8833
# Epoch 21/50
# 68/68 [==============================] - 1s 8ms/step - loss: 0.0695 - accuracy: 0.9833 - val_loss: 0.4659 - val_accuracy: 0.8778
# Epoch 22/50
# 68/68 [==============================] - 0s 4ms/step - loss: 0.0639 - accuracy: 0.9824 - val_loss: 0.4521 - val_accuracy: 0.8861
# Epoch 23/50
# 68/68 [==============================] - 0s 4ms/step - loss: 0.0607 - accuracy: 0.9889 - val_loss: 0.4093 - val_accuracy: 0.8917
# Epoch 24/50
# 68/68 [==============================] - 0s 4ms/step - loss: 0.0618 - accuracy: 0.9852 - val_loss: 0.4340 - val_accuracy: 0.8861
# Epoch 25/50
# 68/68 [==============================] - 0s 4ms/step - loss: 0.0560 - accuracy: 0.9861 - val_loss: 0.4380 - val_accuracy: 0.8861
# Epoch 26/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0518 - accuracy: 0.9889 - val_loss: 0.4418 - val_accuracy: 0.8806
# Epoch 27/50
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0505 - accuracy: 0.9879 - val_loss: 0.4373 - val_accuracy: 0.8806
# Epoch 28/50
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0536 - accuracy: 0.9870 - val_loss: 0.4488 - val_accuracy: 0.8861
# Epoch 29/50
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0486 - accuracy: 0.9907 - val_loss: 0.4486 - val_accuracy: 0.8861
# Epoch 30/50
# 68/68 [==============================] - 1s 8ms/step - loss: 0.0449 - accuracy: 0.9898 - val_loss: 0.4125 - val_accuracy: 0.8917
# Epoch 31/50
# 68/68 [==============================] - 1s 10ms/step - loss: 0.0429 - accuracy: 0.9917 - val_loss: 0.4461 - val_accuracy: 0.8917
# Epoch 32/50
# 68/68 [==============================] - 1s 8ms/step - loss: 0.0416 - accuracy: 0.9889 - val_loss: 0.4481 - val_accuracy: 0.8972
# Epoch 33/50
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0416 - accuracy: 0.9889 - val_loss: 0.4303 - val_accuracy: 0.8972
# Epoch 34/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0429 - accuracy: 0.9889 - val_loss: 0.4205 - val_accuracy: 0.8889
# Epoch 35/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0366 - accuracy: 0.9935 - val_loss: 0.4707 - val_accuracy: 0.8944
# Epoch 36/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0354 - accuracy: 0.9907 - val_loss: 0.4482 - val_accuracy: 0.8944
# Epoch 37/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0349 - accuracy: 0.9935 - val_loss: 0.4680 - val_accuracy: 0.8889
# Epoch 38/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0330 - accuracy: 0.9935 - val_loss: 0.4657 - val_accuracy: 0.8972
# Epoch 39/50
# 68/68 [==============================] - 1s 8ms/step - loss: 0.0338 - accuracy: 0.9907 - val_loss: 0.4921 - val_accuracy: 0.8833
# Epoch 40/50
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0321 - accuracy: 0.9954 - val_loss: 0.4642 - val_accuracy: 0.8972
# Epoch 41/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0293 - accuracy: 0.9954 - val_loss: 0.4869 - val_accuracy: 0.8944
# Epoch 42/50
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0266 - accuracy: 0.9954 - val_loss: 0.4712 - val_accuracy: 0.8889
# Epoch 43/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0265 - accuracy: 0.9972 - val_loss: 0.5230 - val_accuracy: 0.8806
# Epoch 44/50
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0271 - accuracy: 0.9944 - val_loss: 0.4690 - val_accuracy: 0.9000
# Epoch 45/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0231 - accuracy: 0.9981 - val_loss: 0.4799 - val_accuracy: 0.8972
# Epoch 46/50
# 68/68 [==============================] - 1s 9ms/step - loss: 0.0247 - accuracy: 0.9972 - val_loss: 0.5111 - val_accuracy: 0.8917
# Epoch 47/50
# 68/68 [==============================] - 1s 9ms/step - loss: 0.0235 - accuracy: 0.9954 - val_loss: 0.5162 - val_accuracy: 0.8972
# Epoch 48/50
# 68/68 [==============================] - 1s 10ms/step - loss: 0.0218 - accuracy: 0.9991 - val_loss: 0.4981 - val_accuracy: 0.8917
# Epoch 49/50
# 68/68 [==============================] - 1s 9ms/step - loss: 0.0212 - accuracy: 0.9981 - val_loss: 0.5040 - val_accuracy: 0.8944
# Epoch 50/50
# 68/68 [==============================] - 1s 9ms/step - loss: 0.0202 - accuracy: 0.9981 - val_loss: 0.4931 - val_accuracy: 0.8972
# 12/12 [==============================] - 0s 3ms/step
# ACCURACY 0.958217270194986
